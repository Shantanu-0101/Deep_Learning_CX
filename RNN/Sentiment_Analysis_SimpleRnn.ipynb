# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
sequence = tokenizer.texts_to_sequences(docs)
sequence
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequence, padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense

# %%
model = Sequential()
model.add(Embedding(17, output_dim=2, input_length=5))

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam', 'accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 679ms/step
# [[[-0.04036953 -0.01431344]
#   [ 0.03657557 -0.00209552]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]]
#
#  [[ 0.03657557 -0.00209552]
#   [ 0.03657557 -0.00209552]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]]
#
#  [[ 0.01979257 -0.03983967]
#   [ 0.01979257 -0.03983967]
#   [ 0.02802081  0.04998728]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]]
#
#  [[ 0.04497309 -0.02358323]
#   [-0.02158582  0.02596498]
#   [ 0.04497309 -0.02358323]
#   [ 0.03657557 -0.00209552]
#   [ 0.04497309 -0.02358323]]
#
#  [[-0.02342088  0.01916716]
#   [-0.02249615 -0.00110109]
#   [-0.00702137 -0.02079269]
#   [ 0.00475057  0.01497186]
#   [ 0.02146157 -0.04025791]]
#
#  [[ 0.03402208 -0.03374298]
#   [ 0.03402208 -0.03374298]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]]
#
#  [[ 0.0173713   0.04977996]
#   [ 0.0173713   0.04977996]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]]
#
#  [[-0.03969746 -0.04880498]
#   [-0.03969746 -0.04880498]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]]
#
#  [[ 0.0151527  -0.01714655]
#   [-0.03088915 -0.04039328]
#   [-0.00702137 -0.02079269]
#   [ 0.00475057  0.01497186]
#   [ 0.02146157 -0.04025791]]
#
#  [[ 0.03525272  0.02643875]
#   [ 0.03525272  0.02643875]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]
#   [ 0.02146157 -0.04025791]]]

# %%
from keras.datasets import imdb
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense, SimpleRNN, Embedding, Flatten

# %%
(X_train,y_train), (X_test, y_test) = imdb.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
X_train = pad_sequences(X_train, padding='post')
X_test = pad_sequences(X_test, padding='post')

# %%
X_train.shape
# Out:
# (25000, 2494)

# %%
model = Sequential()
model.add(Embedding(10000, 2, input_length=X_train.shape[1]))
model.add(SimpleRNN(32, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=5, validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 140s 175ms/step - accuracy: 0.4955 - loss: 0.6946 - val_accuracy: 0.5003 - val_loss: 0.6932
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 173ms/step - accuracy: 0.4985 - loss: 0.6950 - val_accuracy: 0.5000 - val_loss: 0.6975
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 173ms/step - accuracy: 0.4934 - loss: 0.6947 - val_accuracy: 0.4991 - val_loss: 0.6933
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 173ms/step - accuracy: 0.4968 - loss: 0.6942 - val_accuracy: 0.4984 - val_loss: 0.6946
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 173ms/step - accuracy: 0.4888 - loss: 0.6952 - val_accuracy: 0.5000 - val_loss: 0.6932
